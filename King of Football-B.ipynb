# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopy.geocoders

# %%
csv_path = 'results.csv'
master_data = pd.read_csv(csv_path)
master_df = pd.DataFrame(master_data)
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40839 entries, 0 to 40838
# Data columns (total 9 columns):
# date          40839 non-null object
# home_team     40839 non-null object
# away_team     40839 non-null object
# home_score    40839 non-null int64
# away_score    40839 non-null int64
# tournament    40839 non-null object
# city          40839 non-null object
# country       40839 non-null object
# neutral       40839 non-null bool
# dtypes: bool(1), int64(2), object(6)
# memory usage: 2.5+ MB

# %%
master_df['year']=''
master_df['month']=''
master_df['goal_diff']=''
master_df['home_result']=''
master_df['lat']=''
master_df['lng']=''
master_df['host_continent']=''
master_df['home_continent']=''
master_df['away_continent']=''
master_df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral year month goal_diff home_result lat lng host_continent  \
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False
#
#   home_continent away_continent
# 0
# 1
# 2
# 3
# 4

# %%
# def result(row):
      
#     if row['home_score'] > row['away_score']:
#         return row['home_team']
#     elif row['home_score'] < row['away_score']:
#         return row['away_team']
#     else:
#         return('Tie')
# master_df['results'] = master_df[['home_score','away_score','home_team','away_team']].apply(result,axis=1)
# master_df.head()

# %%
# results['year'] = pd.to_numeric([date.split('-')[0] for date in results['date']])
# results['month'] = pd.to_numeric([date.split('-')[1] for date in results['date']])
# results['day'] = pd.to_numeric([date.split('-')[2] for date in results['date']])

# def find_winners(df):
#     winners = []
#     for i, row in df.iterrows():
#         if row['home_ft'] > row['away_ft']:
#             winners.append(row['home_team'])
#         elif row['home_ft'] < row['away_ft']:
#             winners.append(row['away_team'])
#         else:
#             winners.append('Draw')
#     return winners
# results['winner'] = find_winners(results)
# results.head()

# %%
master_df2=master_df.head()
master_df2
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral year month goal_diff home_result lat lng host_continent  \
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False
#
#   home_continent away_continent
# 0
# 1
# 2
# 3
# 4

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="uci-behnam")
#location = geolocator.geocode(master_df.home_team[0])
#print(location.address)
master_df2['lat']=master_df2['city'].apply(geolocator.geocode)
master_df2['lat2']=master_df2['lat'].apply(lambda x:x.latitude)
#print((location.latitude, location.longitude))
#.apply(lambda x: x.latitude)
master_df2.head()
# Out:
# C:\Users\tobe\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\tobe\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# ...

# %%
# data['date'] = pd.to_datetime(data['date'])
# time = data['date'].iloc[0]
# time.year
# data['month'] = data['date'].apply(lambda time: time.month)
# data['year']  = data['date'].apply(lambda time: time.year)
# data['month'] = data['month'].map({1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', 7:'Jul', 8:'Aug', 9:'Sep', 
#                                  10:'Oct', 11:'Nov', 12:'Dec'})

# %%
# match_count = data['year'].value_counts()
# match_count.head(2)
# plt.figure(figsize=(20,8))
# sns.lineplot(match_count.index, match_count.values, color='red', lw=2)
# plt.title('Number of matches played in each year', fontsize=20)
# plt.ylabel('No of matches', fontsize=12)
# plt.xlabel('Year', fontsize=12)
